# %%
# !unzip -q /content/millions-of-movies.zip

# %%
# !pip install pyspark
# !pip install sentence-transformers

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import col, lower, sum as _sum, when
from pyspark.sql.types import IntegerType
from sklearn.preprocessing import MinMaxScaler
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pickle

# %%
spark = SparkSession.builder.appName("movies_pyspark").getOrCreate()

# %%
df = spark.read.csv('/content/movies.csv', header=True, inferSchema=True)

# %%
null_counts = df.select([_sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df.columns])
null_counts.show()
# Out:
# +---+-----+------+-----------------+--------+----------+--------------------+------------+------+-------+-------+------+-------+------------+----------+-------+--------+-----------+-------------+---------------+
# | id|title|genres|original_language|overview|popularity|production_companies|release_date|budget|revenue|runtime|status|tagline|vote_average|vote_count|credits|keywords|poster_path|backdrop_path|recommendations|
# +---+-----+------+-----------------+--------+----------+--------------------+------------+------+-------+-------+------+-------+------------+----------+-------+--------+-----------+-------------+---------------+
# |  0|    4|210307|                9|  118240|         7|              384902|       51569|     5|      2|  34334|     2| 613810|          27|         5| 224638|  511524|     184582|       498988|         686050|
# +---+-----+------+-----------------+--------+----------+--------------------+------------+------+-------+-------+------+-------+------------+----------+-------+--------+-----------+-------------+---------------+

# %%
df_filled = df.fillna({"genres": '[NO_GENRE]', "credits": '[NO_CREDITS]', 'overview': 'No overview available'})

# %%
df_without_status = df_filled.filter(df_filled.status == 'Released')

# %%
df_year = df_without_status.withColumn("release_year", F.split(F.col("release_date"), "-")[0]).alias('release_year')

# %%
df_released = df_year.filter(df_filled.status == 'Released')

# %%
df_vote = df_released.withColumn("vote_count", col("vote_count").cast(IntegerType())).withColumn("vote_average", col("vote_average").cast(IntegerType()))

m = df_vote.approxQuantile("vote_count", [0.7], 0.01)[0] # Calculate the 70th percentile
C = df_vote.select(F.avg("vote_average")).collect()[0][0] # Calculate the mean vote average

df_weighted = df_vote.withColumn(
    "weighted_rating",
    ((col("vote_average") * col("vote_count")) + (C * m)) / (col("vote_count") + m)
)

df_weighted.show()
# Out:
# +------+--------------------+--------------------+-----------------+--------------------+----------+--------------------+------------+-----------+------------+-------+--------+--------------------+------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+------------------+
# |    id|               title|              genres|original_language|            overview|popularity|production_companies|release_date|     budget|     revenue|runtime|  status|             tagline|vote_average|vote_count|             credits|            keywords|         poster_path|       backdrop_path|     recommendations|release_year|   weighted_rating|
# +------+--------------------+--------------------+-----------------+--------------------+----------+--------------------+------------+-----------+------------+-------+--------+--------------------+------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+------------------+
# |615656|   Meg 2: The Trench|Action-Science Fi...|               en|An exploratory di...|  8763.998|Apelles Entertain...|  2023-08-02|129000000.0| 352056482.0|  116.0|Released|   Back for seconds.|           7|      1365|Jason Statham-Wu ...|based on novel or...|/4m1Au3YkjqsxF8iw...|/qlxy8yo5bcgUw2KA...|1006462-298618-56...|        2023| 6.996598351734084|
# |758323| The Pope's Exorcist|Horror-Mystery-Th...|               en|Father Gabriele A...|  5953.227|Screen Gems-2.0 E...|  2023-04-05| 18000000.0|  65675816.0|  103.0|Released|Inspired by the a...|           7|       545|Russell Crowe-Dan...|spain-rome italy-...|/9JBEPLTPSm0d1mbE...|/hiHGRbyTcbZoLsYY...|713704-296271-502...|        2023| 6.991489649210181|
------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+------------------+
# only showing top 20 rows

# %%
df_weighted.dropDuplicates()
df_weighted.count()
# Out:
# 717058

# %%
df_cols_dropped = df_weighted.drop("id", 'production_companies', 'tagline','keywords', 'poster_path', 'backdrop_path', 'recommendations', 'status', "budget", "revenue", 'release_date', 'popularity', 'vote_count', 'vote_average')

# %%
df_cols_dropped.show()
# Out:
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+
# |               title|              genres|original_language|            overview|runtime|             credits|release_year|   weighted_rating|
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+
# |   Meg 2: The Trench|Action-Science Fi...|               en|An exploratory di...|  116.0|Jason Statham-Wu ...|        2023| 6.996598351734084|
# | The Pope's Exorcist|Horror-Mystery-Th...|               en|Father Gabriele A...|  103.0|Russell Crowe-Dan...|        2023| 6.991489649210181|
# |Deadpool & Wolverine|Action-Comedy-Sci...|               en|A listless Wade W...|  128.0|Ryan Reynolds-Hug...|        2024| 6.998760892925002|
# |Transformers: Ris...|Action-Adventure-...|               en|When a new threat...|  127.0|Anthony Ramos-Dom...|        2023| 6.995390226655514|
# |      Dune: Part Two|Science Fiction-A...|               en|Follow the mythic...|  167.0|Timothée Chalamet...|        2024|    7.997962233298|
# |Venom: The Last D...|Science Fiction-A...|               en|Eddie and Venom a...|  109.0|Tom Hardy-Chiwete...|        2024| 5.993962497464833|
# |Ant-Man and the W...|Action-Adventure-...|               en|Super-Hero partne...|  125.0|Paul Rudd-Evangel...|        2023| 5.998703182243513|
# |           Creed III|        Drama-Action|               en|After dominating ...|  116.0|Michael B. Jordan...|        2023| 6.995887918998902|
# |Insidious: The Re...|Horror-Mystery-Th...|               en|To put their demo...|  107.0|Ty Simpkins-Patri...|        2023| 5.993545749502228|
# |     Despicable Me 4|Animation-Family-...|               en|Gru and Lucy and ...|   94.0|Steve Carell-Kris...|        2024| 6.995282587277927|
# |Spider-Man: Acros...|Action-Adventure-...|               en|After reuniting w...|  140.0|Shameik Moore-Hai...|        2023| 7.996648871494813|
# |Kingdom of the Pl...|Science Fiction-A...|               en|Several generatio...|  145.0|Owen Teague-Freya...|        2024|5.9971599287139865|
# |Beetlejuice Beetl...|Comedy-Fantasy-Ho...|               en|After a family tr...|  105.0|Michael Keaton-Wi...|        2024| 6.995553443510774|
# |   The Eighth Clause|            Thriller|               la|Kat and Borja app...|    0.0|Maite Perroni-Man...|        2022|3.8503044062508285|
# |Aquaman and the L...|Action-Adventure-...|               en|Black Manta still...|  124.0|Patrick Wilson-Ya...|        2023| 5.995182758875507|
# |Shazam! Fury of t...|Action-Comedy-Fan...|               en|"Billy Batson and...|  130.0|Zachary Levi-Ashe...|        2023|5.9977251082150715|
# |Knights of the Zo...|Fantasy-Action-Ad...|               en|When a headstrong...|  113.0|Mackenyu-Madison ...|        2023| 5.992274043366015|
# |Furiosa: A Mad Ma...|Action-Adventure-...|               en|As the world fell...|  149.0|Anya Taylor-Joy-C...|        2024| 6.997916299761775|
# |            Napoleon|   History-War-Drama|               en|An epic that deta...|  158.0|Joaquin Phoenix-V...|        2023| 5.997157715096461|
# |Bad Boys: Ride or...|Action-Crime-Thri...|               en|After their late ...|  115.0|Will Smith-Martin...|        2024| 5.992174567529526|
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+
# only showing top 20 rows

# %%
null_counts = df_cols_dropped.select([_sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df_cols_dropped.columns])
null_counts.show()
# Out:
# +-----+------+-----------------+--------+-------+-------+------------+---------------+
# |title|genres|original_language|overview|runtime|credits|release_year|weighted_rating|
# +-----+------+-----------------+--------+-------+-------+------------+---------------+
# |    4|     0|                0|       0|  33678|      0|       46522|            419|
# +-----+------+-----------------+--------+-------+-------+------------+---------------+

# %%
df_no_na = df_cols_dropped.dropna()
df_no_na.count()
# Out:
# 642315

# %%
from pyspark.sql.functions import concat_ws

df_combined = df_no_na.withColumn(
    "combined_text",
    concat_ws(
        " ",
        "title",
        "genres",
        "original_language",
        "overview",
        "credits"
    )
)

df_combined.show()
# Out:
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+--------------------+
# |               title|              genres|original_language|            overview|runtime|             credits|release_year|   weighted_rating|       combined_text|
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+--------------------+
# |   Meg 2: The Trench|Action-Science Fi...|               en|An exploratory di...|  116.0|Jason Statham-Wu ...|        2023| 6.996598351734084|Meg 2: The Trench...|
# | The Pope's Exorcist|Horror-Mystery-Th...|               en|Father Gabriele A...|  103.0|Russell Crowe-Dan...|        2023| 6.991489649210181|The Pope's Exorci...|
# |Deadpool & Wolverine|Action-Comedy-Sci...|               en|A listless Wade W...|  128.0|Ryan Reynolds-Hug...|        2024| 6.998760892925002|Deadpool & Wolver...|
# |Transformers: Ris...|Action-Adventure-...|               en|When a new threat...|  127.0|Anthony Ramos-Dom...|        2023| 6.995390226655514|Transformers: Ris...|
# |      Dune: Part Two|Science Fiction-A...|               en|Follow the mythic...|  167.0|Timothée Chalamet...|        2024|    7.997962233298|Dune: Part Two Sc...|
# |Venom: The Last D...|Science Fiction-A...|               en|Eddie and Venom a...|  109.0|Tom Hardy-Chiwete...|        2024| 5.993962497464833|Venom: The Last D...|
# |Ant-Man and the W...|Action-Adventure-...|               en|Super-Hero partne...|  125.0|Paul Rudd-Evangel...|        2023| 5.998703182243513|Ant-Man and the W...|
# |           Creed III|        Drama-Action|               en|After dominating ...|  116.0|Michael B. Jordan...|        2023| 6.995887918998902|Creed III Drama-A...|
# |Insidious: The Re...|Horror-Mystery-Th...|               en|To put their demo...|  107.0|Ty Simpkins-Patri...|        2023| 5.993545749502228|Insidious: The Re...|
# |     Despicable Me 4|Animation-Family-...|               en|Gru and Lucy and ...|   94.0|Steve Carell-Kris...|        2024| 6.995282587277927|Despicable Me 4 A...|
# |Spider-Man: Acros...|Action-Adventure-...|               en|After reuniting w...|  140.0|Shameik Moore-Hai...|        2023| 7.996648871494813|Spider-Man: Acros...|
# |Kingdom of the Pl...|Science Fiction-A...|               en|Several generatio...|  145.0|Owen Teague-Freya...|        2024|5.9971599287139865|Kingdom of the Pl...|
# |Beetlejuice Beetl...|Comedy-Fantasy-Ho...|               en|After a family tr...|  105.0|Michael Keaton-Wi...|        2024| 6.995553443510774|Beetlejuice Beetl...|
# |   The Eighth Clause|            Thriller|               la|Kat and Borja app...|    0.0|Maite Perroni-Man...|        2022|3.8503044062508285|The Eighth Clause...|
# |Aquaman and the L...|Action-Adventure-...|               en|Black Manta still...|  124.0|Patrick Wilson-Ya...|        2023| 5.995182758875507|Aquaman and the L...|
# |Shazam! Fury of t...|Action-Comedy-Fan...|               en|"Billy Batson and...|  130.0|Zachary Levi-Ashe...|        2023|5.9977251082150715|Shazam! Fury of t...|
# |Knights of the Zo...|Fantasy-Action-Ad...|               en|When a headstrong...|  113.0|Mackenyu-Madison ...|        2023| 5.992274043366015|Knights of the Zo...|
# |Furiosa: A Mad Ma...|Action-Adventure-...|               en|As the world fell...|  149.0|Anya Taylor-Joy-C...|        2024| 6.997916299761775|Furiosa: A Mad Ma...|
# |            Napoleon|   History-War-Drama|               en|An epic that deta...|  158.0|Joaquin Phoenix-V...|        2023| 5.997157715096461|Napoleon History-...|
# |Bad Boys: Ride or...|Action-Crime-Thri...|               en|After their late ...|  115.0|Will Smith-Martin...|        2024| 5.992174567529526|Bad Boys: Ride or...|
# +--------------------+--------------------+-----------------+--------------------+-------+--------------------+------------+------------------+--------------------+
# only showing top 20 rows

# %%
null_counts = df_combined.select([_sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df_combined.columns])
null_counts.show()
# Out:
# +-----+------+-----------------+--------+-------+-------+------------+---------------+-------------+
# |title|genres|original_language|overview|runtime|credits|release_year|weighted_rating|combined_text|
# +-----+------+-----------------+--------+-------+-------+------------+---------------+-------------+
# |    0|     0|                0|       0|      0|      0|           0|              0|            0|
# +-----+------+-----------------+--------+-------+-------+------------+---------------+-------------+

# %%
df_combined.write.mode("overwrite").parquet("/content/movies.parquet")

# %%
movies = pd.read_parquet('/content/movies.parquet')

movies.columns
# Out:
# Index(['title', 'genres', 'original_language', 'overview', 'runtime',
#        'credits', 'release_year', 'weighted_rating', 'combined_text'],
#       dtype='object')

# %%
movies
# Out:
#                                    title                             genres  \
# 0                      Meg 2: The Trench      Action-Science Fiction-Horror
# 1                    The Pope's Exorcist            Horror-Mystery-Thriller
# 2                   Deadpool & Wolverine      Action-Comedy-Science Fiction
# 3       Transformers: Rise of the Beasts   Action-Adventure-Science Fiction
# 4                         Dune: Part Two          Science Fiction-Adventure
# ...                                  ...                                ...
# 642310                      Tomcat Tales            Documentary-History-War
# 642311                   Strictly Modern                     Comedy-Romance
# 642312                       Your Letter  Animation-Drama-Mystery-Adventure
# 642313            Café Tacvba - Un Viaje                         [NO_GENRE]
# 642314                    Wild Playgirls                         [NO_GENRE]
#
#        original_language                                           overview  \
# 0                     en  An exploratory dive into the deepest depths of...
# 1                     en  Father Gabriele Amorth Chief Exorcist of the V...
# 2                     en  A listless Wade Wilson toils away in civilian ...
# 3                     en  When a new threat capable of destroying the en...
# 4                     en  Follow the mythic journey of Paul Atreides as ...
# ...                  ...                                                ...
# 642310                en  Learn from real-life Top Guns who have flown a...
# 642311                en  Strictly Modern is a 1930 American pre-Code co...
# 642312                ko  Sori Lee is hoping for a fresh start at her ne...
# 642313                en  Un Viaje is the first live album by the rock b...
# 642314                fr  Two men who have the financial problems decide...
#
#        runtime                                            credits  \
# 0        116.0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 1        103.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2        128.0  Ryan Reynolds-Hugh Jackman-Emma Corrin-Matthew...
# 3        127.0  Anthony Ramos-Dominique Fishback-Luna Lauren V...
# 4        167.0  Timothée Chalamet-Zendaya-Rebecca Ferguson-Jav...
# ...        ...                                                ...
# 642310   120.0                                       [NO_CREDITS]
# 642311    63.0  Dorothy Mackaill-Sidney Blackmer-Julanne Johns...
# 642312    97.0  Lee Soo-hyun-Kim Min-ju-Min Seungwoo-Nam Doh-h...
# 642313   120.0  Rubén Albarrán-Emmanuel del Real-Joselo Rangel...
# 642314    84.0  Richard Lemieuvre-Alban Ceray-Uschi Karnat-Dor...
#
#        release_year  weighted_rating  \
# 0              2023         6.996598
# 1              2023         6.991490
# 2              2024         6.998761
# 3              2023         6.995390
# 4              2024         7.997962
# ...             ...              ...
# 642310         2020         2.353348
# 642311         1930         2.353348
# 642312         2024         2.353348
# 642313         2005         2.353348
# 642314         1981         6.225558
#
#                                             combined_text
# 0       Meg 2: The Trench Action-Science Fiction-Horro...
# 1       The Pope's Exorcist Horror-Mystery-Thriller en...
# 2       Deadpool & Wolverine Action-Comedy-Science Fic...
# 3       Transformers: Rise of the Beasts Action-Advent...
# 4       Dune: Part Two Science Fiction-Adventure en Fo...
# ...                                                   ...
# 642310  Tomcat Tales Documentary-History-War en Learn ...
# 642311  Strictly Modern Comedy-Romance en Strictly Mod...
# 642312  Your Letter Animation-Drama-Mystery-Adventure ...
# 642313  Café Tacvba - Un Viaje [NO_GENRE] en Un Viaje ...
# 642314  Wild Playgirls [NO_GENRE] fr Two men who have ...
#
# [642315 rows x 9 columns]

# %%
movies.isna().sum()
# Out:
# title                0
# genres               0
# original_language    0
# overview             0
# runtime              0
# credits              0
# release_year         0
# weighted_rating      0
# combined_text        0
# dtype: int64

# %%
scaler = MinMaxScaler()
numerical_features = ["runtime", 'weighted_rating', "release_year"]

movies[numerical_features] = scaler.fit_transform(movies[numerical_features])

# %%
movies = movies.reset_index(drop=True)

# %%
model1 = SentenceTransformer("all-MiniLM-L6-v2")

text_embeddings1 = model1.encode(movies["combined_text"], show_progress_bar=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/20073 [00:00<?, ?it/s]

# %%
text_embeddings1 = np.array(text_embeddings1)

movie_embeddings1 = np.hstack((text_embeddings1, movies[numerical_features].values))

# %%
knn = NearestNeighbors(n_neighbors=10, metric="cosine", algorithm="brute")

model = knn.fit(movie_embeddings1)

# %%
def get_recommendations(movie_title):
    idx = movies[movies["title"] == movie_title].index[0]
    distances, indices = knn.kneighbors([movie_embeddings1[idx]], n_neighbors=9)

    recommended_movies = [movies.iloc[i]["title"] for i in indices.flatten()[1:]]
    return recommended_movies

# %%
# Save the trained model using pickle
with open('recommendation_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Save the movie embeddings
with open('movie_embeddings.pkl', 'wb') as f:
  pickle.dump(movie_embeddings1, f)

# Save the movies DataFrame
with open('movies_df.pkl', 'wb') as f:
    pickle.dump(movies, f)
